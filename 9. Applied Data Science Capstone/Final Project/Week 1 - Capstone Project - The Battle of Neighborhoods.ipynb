# %% [markdown]
# # Capstone Project - The Battle of Neighborhoods

# %% [markdown]
# -----
# ##  IBM - Data Science - Applied Data Science Capstone

# %% [markdown]
# -------
# ## Table of Content

# %% [markdown]
#  + ### Description of Problem
#  + ### Data
#  + ### Description of Method
#  + ### Analysis
#  + ### Result and Discussion
#  + ### Conclusion

# %% [markdown]
# -------------
# # 1. Description of Problem

# %% [markdown]
# ### 1.1 Background
#     In this Capstone Project, I am planning to find a suitable place to open a restaurant in Toronto, Canada.  The idea behind this project is that I want to share my home country's special food to Canadians and my compatriots. As a result, I could share my culture with others. Openning a restaurant is a useful and effciency approach to share my culture to others.

# %% [markdown]
# ### 1.2 Business Problem
#     The Goal of this project is to find the most suitable place for openning a restaurant in Toronto. The Question is that how we choose the best location for openning a restaurant, including how many factors we need to consider, how we evaluate those factors and methods that we use to solve this problme. In addtion, we also need to get reliable data and how we process our data.

# %% [markdown]
# # 2. Data

# %% [markdown]
# ##### 2.1 To solve this problem, we need some data as follow
# + ##### List of neighborhoods and bouroughs of Toronto
# + ##### Latitud and Logitude of these neighborhoods.
# + ##### Venue Data related to Restaurants
# ##### These data will help us find the most suitable place for openning restaurants.
#
# #### (These data are temporary, I will add or delete data later as I continue completing my project)

# %% [markdown]
# #### 2.2 how we get these data
# + ##### Scrapping of Toronto neighborhodds via Wikipedia
# + ####
